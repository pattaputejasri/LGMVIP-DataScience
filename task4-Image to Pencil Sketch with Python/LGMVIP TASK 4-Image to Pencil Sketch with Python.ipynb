# %% [markdown]
# # Let'sGrowMore Virtual Internship Programme
# ## Name : PATTAPU TEJA SRI
# ### BEGINNER LEVEL Task 4 : Image to Pencil Sketch with Python
#
# ### Import required module

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read the image

# %%
image = cv2.imread("theweeknd.jpg")
plt.imshow(image)

# %% [markdown]
# ### convert and create a new image in grayscale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image)

# %% [markdown]
# convert and create a new image in grayscale

# %%
inverted = 255-gray_image
plt.imshow(inverted)

# %% [markdown]
# convert the grayscale image to blur

# %%
blur = cv2.GaussianBlur(inverted, (21, 21), 0)
plt.imshow(blur)

# %% [markdown]
# Again invert the blurred image

# %%
invertedblur = 255-blur
plt.imshow(invertedblur)

# %% [markdown]
# Now convert the image into pencil sketch

# %%
sketch = cv2.divide(gray_image, invertedblur, scale=256.0)
plt.imshow(sketch)

# %% [markdown]
# Save the image in current working directory with the specific name

# %%
cv2.imwrite("sketch.png", sketch)
# Out:
# True

# %% [markdown]
# Display the image

# %%
plt.imshow(sketch,cmap="gray")
